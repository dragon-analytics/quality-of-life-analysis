# %% [markdown]
# ## Requests
#
# https://cran.r-project.org/web/packages/jsonlite/vignettes/json-apis.html

# %%
library(jsonlite)

# %%
key <- "api_key=<YOUR_KEY>"
url <- "http://www.numbeo.com:8008/api/cities?"

# %%
req <- fromJSON(paste0(url, key))

# %%
req$cities
# Out:
#       country        city             latitude   city_id longitude
# 1     Algeria        Abelessa         22.18778    1       4.0695454
# 2     Algeria        Adrar            27.87561    2      -0.2907496
# 3     Algeria        Aflu             34.11388    3       2.0972620
# 4     Algeria        Algiers          36.75289    4       3.0420480
# 5     Algeria        Annaba           36.90286    5       7.7555430
# 6     Algeria        Batna            35.55299    6       6.1775324
# 7     Algeria        Bechar           31.61610    7      -2.2166234
# 8     Algeria        Bejaia           36.75000    8       5.0666667
# 9     Algeria        Biskra           34.85076    9       5.7280575
# 10    Algeria        Blida            36.48050   10       2.8339050
# 11    Algeria        Constantine      36.35000   11       6.6000000
# 12    Algeria        Djelfa           34.66667   12       3.2500000
# 13    Algeria        Djemila          36.31442   13       5.7377948
# ...
